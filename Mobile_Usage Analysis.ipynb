# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmedhussein2001/D/blob/main/Mobile_Usage%20Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# ## Read Data

# %%
df = pd.read_csv("/kaggle/input/mobile-usage-dataset/mobile_life_sample.csv")
df
# Out:
#      User_ID        Date  Screen_Time (mins)  Battery_Level (%) Network_Type  \
# 0     User_1  2024-01-01                 455                 99           4G
# 1     User_1  2024-01-02                 567                 42         WiFi
# 2     User_1  2024-01-03                 334                 83           4G
# 3     User_1  2024-01-04                 579                 93           4G
# 4     User_1  2024-01-05                 115                 68         WiFi
# ..       ...         ...                 ...                ...          ...
# 195  User_20  2024-01-06                 257                 91           5G
# 196  User_20  2024-01-07                 387                 50           5G
# 197  User_20  2024-01-08                 335                 63           4G
# 198  User_20  2024-01-09                 260                 54           5G
# 199  User_20  2024-01-10                 212                 33           5G
#
# ...

# %%
df.columns
# Out:
# Index(['User_ID', 'Date', 'Screen_Time (mins)', 'Battery_Level (%)',
#        'Network_Type', 'Data_Usage (MB)', 'Steps_Count',
#        'Call_Duration (mins)', 'App_Usage (Top App)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   User_ID               200 non-null    object
#  1   Date                  200 non-null    object
#  2   Screen_Time (mins)    200 non-null    int64
#  3   Battery_Level (%)     200 non-null    int64
#  4   Network_Type          200 non-null    object
#  5   Data_Usage (MB)       200 non-null    float64
#  6   Steps_Count           200 non-null    int64
#  7   Call_Duration (mins)  200 non-null    int64
#  8   App_Usage (Top App)   200 non-null    object
# dtypes: float64(1), int64(4), object(4)
# memory usage: 14.2+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   User_ID               200 non-null    object
#  1   Date                  200 non-null    datetime64[ns]
#  2   Screen_Time (mins)    200 non-null    int64
#  3   Battery_Level (%)     200 non-null    int64
#  4   Network_Type          200 non-null    object
#  5   Data_Usage (MB)       200 non-null    float64
#  6   Steps_Count           200 non-null    int64
#  7   Call_Duration (mins)  200 non-null    int64
#  8   App_Usage (Top App)   200 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(3)
# memory usage: 14.2+ KB

# %%
df.describe().T
# Out:
#                       count                 mean                  min  \
# Date                    200  2024-01-05 12:00:00  2024-01-01 00:00:00
# Screen_Time (mins)    200.0               314.98                 32.0
# Battery_Level (%)     200.0               53.325                  5.0
# Data_Usage (MB)       200.0            1033.8538                68.57
# Steps_Count           200.0             10714.57               1039.0
# Call_Duration (mins)  200.0                58.22                  0.0
#
#                                       25%                  50%  \
# Date                  2024-01-03 00:00:00  2024-01-05 12:00:00
# Screen_Time (mins)                  160.0                329.5
# Battery_Level (%)                    27.0                 54.0
# Data_Usage (MB)                    508.45              1050.37
# Steps_Count                        7007.5              11140.5
# Call_Duration (mins)                 26.5                 57.5
#
# ...

# %%
df.isna().sum()
# Out:
# User_ID                 0
# Date                    0
# Screen_Time (mins)      0
# Battery_Level (%)       0
# Network_Type            0
# Data_Usage (MB)         0
# Steps_Count             0
# Call_Duration (mins)    0
# App_Usage (Top App)     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Visualization

# %%
num_val = df.select_dtypes(include=np.number)
for col in num_val :
    sns.histplot(data=df,x = col , kde=True, bins=10)
    plt.show()

# %%
plt.plot(df["Date"], df['Screen_Time (mins)'], marker='o', linestyle='-', color='b')
plt.xlabel("Date")
plt.ylabel("Value")
plt.title("Time Series Visualization")
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
sns.lineplot(x=df["Date"], y=df['Call_Duration (mins)'], marker='o')
plt.xticks(rotation=45)
plt.title("Seaborn Time Series Plot")
plt.show()

# %%
sns.countplot(y=df['App_Usage (Top App)'],order= df['App_Usage (Top App)'].value_counts().index,palette='magma')
plt.title('The top app usage counts')
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x=df['App_Usage (Top App)'],y=df['Battery_Level (%)'], data=df,palette='coolwarm')
plt.title('The app wise battery level')
plt.show()
